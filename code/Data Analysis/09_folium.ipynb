# %% [markdown]
# ## 09. Folium
# - 지도시각화 라이브러리

# %%
import folium

# %%
m = folium.Map(location=[37.61119807384533, 126.91731049700418],
              zoom_start=18)

# 기본 마커
folium.Marker([37.61119807384533, 126.91731049700418],
              popup="Subway",
              tooltip="구산역",
              icon=folium.Icon(color="black", icon="fa-solid fa-bus", prefix="fa-solid")
              ).add_to(m)

# 원형 마커
folium.CircleMarker(
  [37.61020411781574, 126.9133136519163],
  radius=100,
  color="#adcdff",
  fill_color ="#1c73ff",
  popup="CircleMarker",
  tooltip="tooltip"
).add_to(m)

# 클릭한 곳에 마커 추가
m.add_child(folium.ClickForMarker(popup="내가 클릭한 곳"))

# 클릭한 곳의 위도와 경도 표시
m.add_child(folium.LatLngPopup())

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4589eab9fe1c26654c60c046462f32df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4589eab9fe1c26654c60c046462f32df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4589eab9fe1c26654c60c046462f32df = L.map(
#                 &quot;map_4589eab9fe1c26654c60c046462f32df&quot;,
#                 {
#                     center: [37.61119807384533, 126.91731049700418],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e619ca093b12f0ba2c2cda8337993e5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4589eab9fe1c26654c60c046462f32df);
#
#
#             var marker_6aab7801e6e7a58d24d218ce5031ba2f = L.marker(
#                 [37.61119807384533, 126.91731049700418],
#                 {}
#             ).addTo(map_4589eab9fe1c26654c60c046462f32df);
#
#
#             var icon_21bd44c7e785ec1d6cea477fa80e5d39 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-bus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_6aab7801e6e7a58d24d218ce5031ba2f.setIcon(icon_21bd44c7e785ec1d6cea477fa80e5d39);
#
#
#         var popup_e030961c82970bb57dbba825df31a6a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b44115abf2743d416a482dbc4bd4d47f = $(`&lt;div id=&quot;html_b44115abf2743d416a482dbc4bd4d47f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Subway&lt;/div&gt;`)[0];
#                 popup_e030961c82970bb57dbba825df31a6a5.setContent(html_b44115abf2743d416a482dbc4bd4d47f);
#
#
#
#         marker_6aab7801e6e7a58d24d218ce5031ba2f.bindPopup(popup_e030961c82970bb57dbba825df31a6a5)
#         ;
#
#
#
#
#             marker_6aab7801e6e7a58d24d218ce5031ba2f.bindTooltip(
#                 `&lt;div&gt;
#                      구산역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_44b0302e05d95271ba3ffdce63aca067 = L.circleMarker(
#                 [37.61020411781574, 126.9133136519163],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#adcdff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1c73ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4589eab9fe1c26654c60c046462f32df);
#
#
#         var popup_8f2d9397aa8f19c585032a05b0c47043 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26bcdf1c7d574508ce63e563bc3e1b26 = $(`&lt;div id=&quot;html_26bcdf1c7d574508ce63e563bc3e1b26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CircleMarker&lt;/div&gt;`)[0];
#                 popup_8f2d9397aa8f19c585032a05b0c47043.setContent(html_26bcdf1c7d574508ce63e563bc3e1b26);
#
#
#
#         circle_marker_44b0302e05d95271ba3ffdce63aca067.bindPopup(popup_8f2d9397aa8f19c585032a05b0c47043)
#         ;
#
#
#
#
#             circle_marker_44b0302e05d95271ba3ffdce63aca067.bindTooltip(
#                 `&lt;div&gt;
#                      tooltip
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#                 function newMarker(e){
#                     var new_mark = L.marker().setLatLng(e.latlng).addTo(map_4589eab9fe1c26654c60c046462f32df);
#                     new_mark.dragging.enable();
#                     new_mark.on(&#x27;dblclick&#x27;, function(e){ map_4589eab9fe1c26654c60c046462f32df.removeLayer(e.target)})
#                     var lat = e.latlng.lat.toFixed(4),
#                        lng = e.latlng.lng.toFixed(4);
#                     new_mark.bindPopup(`내가 클릭한 곳`);
#                     };
#                 map_4589eab9fe1c26654c60c046462f32df.on(&#x27;click&#x27;, newMarker);
#
#
#                 var lat_lng_popup_d59dc87f5bf212f383917d7429cdb369 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_d59dc87f5bf212f383917d7429cdb369
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_4589e

# %%
# 실습2.
import folium
import pandas as pd

df = pd.read_csv("dataset/택시승차대 현황.csv", encoding="CP949")

taxi = df.loc[:, ["위치명","위도","경도"]]
latitude = taxi["위도"].mean()
longitude = taxi["경도"].mean()
m = folium.Map([latitude, longitude], zoom_start=13)

for idx, row in taxi.iterrows():
  # print(idx, row["위치명"], row["위도"], row["경도"])
  folium.Marker(
    [row["위도"],row["경도"]],
    tooltip = row["위치명"],
    icon=folium.Icon(color="orange", icon="fa-solid fa-taxi", prefix="fa-solid")
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_894dd8daf6b31d4c27f864074a26815c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_894dd8daf6b31d4c27f864074a26815c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_894dd8daf6b31d4c27f864074a26815c = L.map(
#                 &quot;map_894dd8daf6b31d4c27f864074a26815c&quot;,
#                 {
#                     center: [37.55052018231854, 126.93522259155674],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1b9cb9b795ef4b39fb1c28c9e600b40 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_894dd8daf6b31d4c27f864074a26815c);
#
#
#             var marker_abb7afef677ef75ca1c4c2d26077f957 = L.marker(
#                 [37.5453970345156, 126.952564116178],
#                 {}
#             ).addTo(map_894dd8daf6b31d4c27f864074a26815c);
#
#
#             var icon_50dc909ca9078bef668ec1edf35aa764 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-taxi&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_abb7afef677ef75ca1c4c2d26077f957.setIcon(icon_50dc909ca9078bef668ec1edf35aa764);
#
#
#             marker_abb7afef677ef75ca1c4c2d26077f957.bindTooltip(
#                 `&lt;div&gt;
#                      신용보증기금 마포지점 앞
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_962b64837c785f2df89151182e176de7 = L.marker(
#                 [37.5520005467366, 126.95651212572],
#                 {}
#             ).addTo(map_894dd8daf6b31d4c27f864074a26815c);
#
#
#             var icon_4eb0b8f387c9d3529d66b9561ef8a3b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-taxi&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_962b64837c785f2df89151182e176de7.setIcon(icon_4eb0b8f387c9d3529d66b9561ef8a3b0);
#
#
#             marker_962b64837c785f2df89151182e176de7.bindTooltip(
#                 `&lt;div&gt;
#                      마포SK허브 빌딩 앞
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dd9c8b11371b768dbbda19b71e63a128 = L.marker(
#                 [37.541448169111, 126.947232985498],
#                 {}
#             ).addTo(map_894dd8daf6b31d4c27f864074a26815c);
#
#
#             var icon_f3e9e6f7d754e200692bc5c495160079 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-taxi&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_dd9c8b11371b768dbbda19b71e63a128.setIcon(icon_f3e9e6f7d754e200692bc5c495160079);
#
#
#             marker_dd9c8b11371b768dbbda19b71e63a128.bindTooltip(
#                 `&lt;div&gt;
#                      트라팰리스빌딩 앞
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c7d158fce2b37546f0897cefe416f6d3 = L.marker(
#                 [37.5484275320782, 126.916896449905],
#                 {}
#             ).addTo(map_894dd8daf6b31d4c27f864074a26815c);
#
#
#             var icon_74993f5bed9e82e4f688959ab3446577 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-taxi&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_c7d158fce2b37546f0897cefe416f6d3.setIcon(icon_74993f5bed9e82e4f688959ab3446577);
#
#
#             marker_c7d158fce2b37546f0897cefe416f6d3.bindTooltip(
#                 `&lt;div&gt;
#                      주식회사 메칸더브이 앞(혜당한방병원 건너)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6a91054783a764750b6af220640c1675 = L.marker(
#                 [37.55371161031, 126.935188539995],
#                 {}
#             ).addTo(map_894dd8daf6b31d4c27f864074a26815c);
#
#
#             var icon_1a9a5563378877f0fc3269a4ab35c15e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-taxi&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColo
